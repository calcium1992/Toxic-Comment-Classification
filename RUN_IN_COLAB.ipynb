# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/Toxic-Comment-Classification/')
for root, dirs, files in os.walk(".", topdown=False):
   for name in files:
      print(os.path.join(root, name))
# Out:
# ./hiera/model=transformer/hyperparameters.yaml
# ./hiera/model=naivebayes/hyperparameters.yaml
# ./hiera/model=cnn/hyperparameters.yaml
# ./hiera/model=cnnglove/hyperparameters.yaml
# ./hiera/default.yaml
# ./config/cnn_config.yaml
# ./config/nb_config.yaml
# ./config/cnnglove_config.yaml
# ./config/transformer_config.yaml
# ./data/glove/glove.twitter.27B.200d.txt
# ./data/train.csv
# ./data/test.csv
# ./data/submission.csv
# ./module/__pycache__/__init__.cpython-36.pyc
# ./module/__pycache__/predictor.cpython-36.pyc
# ./module/__pycache__/trainer.cpython-36.pyc
# ./module/__pycache__/preprocessor.cpython-36.pyc
# ./module/model/__pycache__/naivebayes.cpython-36.pyc
# ./module/model/__pycache__/__init__.cpython-36.pyc
# ./module/model/__pycache__/transformer.cpython-36.pyc
# ./module/model/__pycache__/cnn.cpython-36.pyc
# ./module/model/naivebayes.py
# ./module/model/__init__.py
# ./module/model/transformer.py
# ./module/model/cnn.py
# ./module/__init__.py
# ./module/predictor.py
# ./module/preprocessor.py
# ./module/trainer.py
# ./README.md
# ./requirements.txt
# ./run_cnn.py
# ./run_nb.py
# ./run_cnnglove.py
# ./RUN_IN_COLAB.ipynb
# ./run_transformer.py

# %% [markdown]
# # Build Environment

# %%
# !pip3 install -r requirements.txt
# Out:
# Requirement already satisfied: himl in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 2)) (1.19.5)
# Requirement already satisfied: pyyaml==5.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (5.1)
# Requirement already satisfied: folium==0.2.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 4)) (0.2.1)
# Requirement already satisfied: urllib3==1.25.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 5)) (1.25)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 6)) (2.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 7)) (1.1.5)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 8)) (0.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 9)) (2.4.3)
# Requirement already satisfied: deepmerge>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from himl->-r requirements.txt (line 1)) (0.1.1)
# Requirement already satisfied: botocore>=1.12 in /usr/local/lib/python3.6/dist-packages (from himl->-r requirements.txt (line 1)) (1.20.5)
# Requirement already satisfied: boto3>=1.9.110 in /usr/local/lib/python3.6/dist-packages (from himl->-r requirements.txt (line 1)) (1.17.5)
# Requirement already satisfied: backports.functools-lru-cache>=1.5 in /usr/local/lib/python3.6/dist-packages (from himl->-r requirements.txt (line 1)) (1.6.1)
# Requirement already satisfied: pathlib2>=2.3.4 in /usr/local/lib/python3.6/dist-packages (from himl->-r requirements.txt (line 1)) (2.3.5)
# Requirement already satisfied: hvac>=0.9.3 in /usr/local/lib/python3.6/dist-packages (from himl->-r requirements.txt (line 1)) (0.10.8)
# Requirement already satisfied: lru-cache>=0.2.3 in /usr/local/lib/python3.6/dist-packages (from himl->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.6/dist-packages (from folium==0.2.1->-r requirements.txt (line 4)) (2.11.3)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (0.36.2)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (1.12)
# Requirement already satisfied: h5py~=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (2.10.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (3.12.4)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (2.4.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (1.6.3)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (3.7.4.3)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (1.12.1)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (0.3.3)
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (2.4.1)
# Requirement already satisfied: grpcio~=1.32.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (1.32.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (1.15.0)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (0.10.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (1.1.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->-r requirements.txt (line 7)) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->-r requirements.txt (line 7)) (2.8.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn->-r requirements.txt (line 8)) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->-r requirements.txt (line 9)) (1.4.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from botocore>=1.12->himl->-r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3>=1.9.110->himl->-r requirements.txt (line 1)) (0.3.4)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from hvac>=0.9.3->himl->-r requirements.txt (line 1)) (2.23.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2->folium==0.2.1->-r requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.9.2->tensorflow->-r requirements.txt (line 6)) (53.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (3.3.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (0.4.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (1.25.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (1.0.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn->-r requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.21.0->hvac>=0.9.3->himl->-r requirements.txt (line 1)) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.21.0->hvac>=0.9.3->himl->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.21.0->hvac>=0.9.3->himl->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (3.4.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (4.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (4.2.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (3.4.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (0.4.8)

# %% [markdown]
# # Run Naive Bayes

# %%
# !himl hiera/model=naivebayes/ --output-file config/nb_config.yaml

# %%
# !python run_nb.py --config config/nb_config.yaml
# Out:
# 2021-02-10 22:57:59.808713: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-10 22:58:40,967 accuracy:0.9037642045454546
# 2021-02-10 22:58:40,967
#               precision    recall  f1-score   support
#
#            0       0.79      0.60      0.68      4591
#            1       0.42      0.41      0.42       485
#            2       0.74      0.59      0.65      2527
#            3       0.14      0.03      0.05       131
#            4       0.68      0.53      0.59      2362
#            5       0.31      0.10      0.15       430
#
#    micro avg       0.72      0.55      0.62     10526
#    macro avg       0.51      0.38      0.43     10526
# weighted avg       0.71      0.55      0.61     10526
#  samples avg       0.98      0.95      0.93     10526

# %% [markdown]
# # Run CNN

# %%
# !himl hiera/model=cnn/ --output-file config/cnn_config.yaml

# %%
# !python run_cnn.py --config config/cnn_config.yaml
# Out:
# 2021-02-10 22:58:47.191487: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# /content/drive/My Drive/Colab Notebooks/Toxic-Comment-Classification/module/preprocessor.py:129: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(dataset_ids)
# 2021-02-10 22:59:26.867294: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-10 22:59:26.868351: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-02-10 22:59:26.901247: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 22:59:26.901885: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-02-10 22:59:26.901966: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-10 22:59:26.904813: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-02-10 22:59:26.904907: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-02-10 22:59:26.907613: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-02-10 22:59:26.908114: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-02-10 22:59:26.911076: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-02-10 22:59:26.911975: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-02-10 22:59:26.917251: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-02-10 22:59:26.917396: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 22:59:26.917963: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 22:59:26.918467: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-02-10 22:59:26.919004: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-10 22:59:26.919155: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 22:59:26.919680: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-02-10 22:59:26.919717: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-10 22:59:26.919751: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-02-10 22:59:26.919777: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-02-10 22:59:26.919800: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-02-10 22:59:26.919820: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-02-10 22:59:26.919839: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-02-10 22:59:26.919860: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-02-10 22:59:26.919883: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-02-10 22:59:26.919950: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 22:59:26.920549: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 22:59:26.921034: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-02-10 22:59:26.921110: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-10 22:59:27.600203: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-02-10 22:59:27.600262: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-02-10 22:59:27.600288: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-02-10 22:59:27.600501: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 22:59:27.601071: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 22:59:27.601689: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 22:59:27.602177: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-02-10 22:59:27.602227: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13960 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 128, 128)          21524224
# _________________________________________________________________
# conv1d (Conv1D)              (None, 128, 128)          114816
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 64, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 64, 256)           164096
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 32, 256)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 32, 512)           393728
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 16, 512)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1048704
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 774
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 42
# =================================================================
# Total params: 23,246,384
# Trainable params: 23,246,384
# Non-trainable params: 0
# _________________________________________________________________
# 2021-02-10 22:59:27.954153: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-02-10 22:59:27.954623: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2199995000 Hz
# Epoch 1/2
# 2021-02-10 22:59:28.713438: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-02-10 22:59:29.071462: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 3491/3491 [==============================] - 698s 198ms/step - loss: 0.0920 - accuracy: 0.8746 - val_loss: 0.0552 - val_accuracy: 0.9938
# Epoch 2/2
# 3491/3491 [==============================] - 687s 197ms/step - loss: 0.0442 - accuracy: 0.9795 - val_loss: 0.0517 - val_accuracy: 0.9938
# 2021-02-10 23:22:36,371 accuracy:0.918511864973262
# 2021-02-10 23:22:36,371
#               precision    recall  f1-score   support
#
#            0       0.84      0.74      0.79      4591
#            1       0.66      0.15      0.24       485
#            2       0.84      0.72      0.78      2527
#            3       1.00      0.00      0.00       131
#            4       0.75      0.65      0.70      2362
#            5       1.00      0.00      0.00       430
#
#    micro avg       0.82      0.65      0.72     10526
#    macro avg       0.85      0.38      0.42     10526
# weighted avg       0.82      0.65      0.70     10526
#  samples avg       0.98      0.96      0.95     10526

# %% [markdown]
# # Run CNN with Glove

# %%
# !himl hiera/model=cnnglove/ --output-file config/cnnglove_config.yaml

# %%
# !python run_cnnglove.py --config config/cnnglove_config.yaml
# Out:
# 2021-02-10 23:22:52.960759: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# tcmalloc: large alloc 1909628928 bytes == 0x9c99a000 @  0x7fbf7b071001 0x7fbf78aaf4ff 0x7fbf78affb08 0x7fbf78b03ac7 0x7fbf78ba21a3 0x50a4a5 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03 0x634e72 0x634f27 0x6386df 0x639281 0x4b0dc0 0x7fbf7ac6cbf7 0x5b259a
# /content/drive/My Drive/Colab Notebooks/Toxic-Comment-Classification/module/preprocessor.py:129: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(dataset_ids)
# 2021-02-10 23:24:36.762457: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-10 23:24:36.771329: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-02-10 23:24:36.803539: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 23:24:36.804115: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-02-10 23:24:36.804169: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-10 23:24:36.806975: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-02-10 23:24:36.807063: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-02-10 23:24:36.809788: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-02-10 23:24:36.810579: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-02-10 23:24:36.813686: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-02-10 23:24:36.814729: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-02-10 23:24:36.820020: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-02-10 23:24:36.820161: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 23:24:36.820768: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 23:24:36.821272: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-02-10 23:24:36.821768: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-10 23:24:36.821926: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 23:24:36.822455: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-02-10 23:24:36.822493: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-10 23:24:36.822528: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-02-10 23:24:36.822552: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-02-10 23:24:36.822574: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-02-10 23:24:36.822595: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-02-10 23:24:36.822614: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-02-10 23:24:36.822635: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-02-10 23:24:36.822655: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-02-10 23:24:36.822728: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 23:24:36.823271: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 23:24:36.823764: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-02-10 23:24:36.823847: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-10 23:24:37.423456: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-02-10 23:24:37.423516: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-02-10 23:24:37.423533: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-02-10 23:24:37.423739: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 23:24:37.424329: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 23:24:37.424869: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 23:24:37.425355: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-02-10 23:24:37.425405: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13960 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2021-02-10 23:24:37.440133: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 954812800 exceeds 10% of free system memory.
# 2021-02-10 23:24:38.566967: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 954812800 exceeds 10% of free system memory.
# 2021-02-10 23:24:38.953321: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 954812800 exceeds 10% of free system memory.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 128, 200)          238703200
# _________________________________________________________________
# conv1d (Conv1D)              (None, 128, 128)          179328
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 64, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 64, 256)           164096
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 32, 256)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 32, 512)           393728
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 16, 512)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1048704
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 774
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 42
# =================================================================
# Total params: 240,489,872
# Trainable params: 1,786,672
# Non-trainable params: 238,703,200
# _________________________________________________________________
# 2021-02-10 23:24:39.971461: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-02-10 23:24:39.971974: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2199995000 Hz
# Epoch 1/2
# 2021-02-10 23:24:40.618495: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-02-10 23:24:42.052451: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 3491/3491 [==============================] - 32s 7ms/step - loss: 0.0901 - accuracy: 0.8345 - val_loss: 0.0530 - val_accuracy: 0.9938
# Epoch 2/2
# 3491/3491 [==============================] - 24s 7ms/step - loss: 0.0541 - accuracy: 0.9849 - val_loss: 0.0526 - val_accuracy: 0.9938
# 2021-02-10 23:25:39,693 accuracy:0.9183029745989305
# 2021-02-10 23:25:39,694
#               precision    recall  f1-score   support
#
#            0       0.86      0.73      0.79      4591
#            1       1.00      0.00      0.00       485
#            2       0.87      0.68      0.76      2527
#            3       1.00      0.00      0.00       131
#            4       0.83      0.49      0.62      2362
#            5       1.00      0.00      0.00       430
#
#    micro avg       0.86      0.59      0.70     10526
#    macro avg       0.93      0.32      0.36     10526
# weighted avg       0.87      0.59      0.66     10526
#  samples avg       0.99      0.95      0.95     10526

# %% [markdown]
# # Run Transformer with Glove

# %%
# !himl hiera/model=transformer/ --output-file config/transformer_config.yaml

# %%
# !python run_transformer.py --config config/transformer_config.yaml
# Out:
# 2021-02-10 23:25:58.068516: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# tcmalloc: large alloc 1909628928 bytes == 0x9cb94000 @  0x7fde48b64001 0x7fde465a24ff 0x7fde465f2b08 0x7fde465f6ac7 0x7fde466951a3 0x50a4a5 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03 0x634e72 0x634f27 0x6386df 0x639281 0x4b0dc0 0x7fde4875fbf7 0x5b259a
# /content/drive/My Drive/Colab Notebooks/Toxic-Comment-Classification/module/preprocessor.py:129: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(dataset_ids)
# confirm
# 2021-02-10 23:27:42.510118: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-10 23:27:42.519920: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-02-10 23:27:42.552526: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 23:27:42.553144: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-02-10 23:27:42.553187: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-10 23:27:42.555504: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-02-10 23:27:42.555598: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-02-10 23:27:42.557460: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-02-10 23:27:42.558210: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-02-10 23:27:42.560443: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-02-10 23:27:42.561346: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-02-10 23:27:42.565691: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-02-10 23:27:42.565896: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 23:27:42.566553: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 23:27:42.567080: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-02-10 23:27:42.567621: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-10 23:27:42.567761: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 23:27:42.568314: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-02-10 23:27:42.568364: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-10 23:27:42.568408: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-02-10 23:27:42.568436: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-02-10 23:27:42.568461: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-02-10 23:27:42.568488: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-02-10 23:27:42.568512: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-02-10 23:27:42.568535: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-02-10 23:27:42.568559: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-02-10 23:27:42.568638: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 23:27:42.569200: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 23:27:42.569713: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-02-10 23:27:42.569767: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-10 23:27:43.165312: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-02-10 23:27:43.165384: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-02-10 23:27:43.165405: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-02-10 23:27:43.165638: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 23:27:43.166240: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 23:27:43.166826: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 23:27:43.167340: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-02-10 23:27:43.167398: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13960 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2021-02-10 23:27:43.237442: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 954812800 exceeds 10% of free system memory.
# 2021-02-10 23:27:44.343123: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 954812800 exceeds 10% of free system memory.
# 2021-02-10 23:27:44.707331: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 954812800 exceeds 10% of free system memory.
# WARNING:tensorflow:AutoGraph could not transform <bound method SelfAttention.call of <module.model.transformer.SelfAttention object at 0x7fddea548e10>> and will run it as-is.
# Cause: mangled names are not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 2021-02-10 23:27:45,547 AutoGraph could not transform <bound method SelfAttention.call of <module.model.transformer.SelfAttention object at 0x7fddea548e10>> and will run it as-is.
# Cause: mangled names are not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128)]             0
# _________________________________________________________________
# token_and_position_embedding (None, 128, 200)          238743200
# _________________________________________________________________
# transformer_encoder (Transfo (None, 128, 200)          213128
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 200)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                12864
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 6)                 390
# _________________________________________________________________
# dense_8 (Dense)              (None, 6)                 42
# =================================================================
# Total params: 238,969,624
# Trainable params: 266,424
# Non-trainable params: 238,703,200
# _________________________________________________________________
# 2021-02-10 23:27:45.777619: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-02-10 23:27:45.778069: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2199995000 Hz
# Epoch 1/10
# 2021-02-10 23:27:47.246604: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 3491/3491 [==============================] - 44s 12ms/step - loss: 0.0980 - accuracy: 0.7829 - val_loss: 0.0562 - val_accuracy: 0.9903
# Epoch 2/10
# 3491/3491 [==============================] - 41s 12ms/step - loss: 0.0564 - accuracy: 0.9562 - val_loss: 0.0558 - val_accuracy: 0.9505
# Epoch 3/10
# 3491/3491 [==============================] - 41s 12ms/step - loss: 0.0527 - accuracy: 0.9472 - val_loss: 0.0531 - val_accuracy: 0.9650
# Epoch 4/10
# 3491/3491 [==============================] - 41s 12ms/step - loss: 0.0488 - accuracy: 0.9692 - val_loss: 0.0503 - val_accuracy: 0.9910
# Epoch 5/10
# 3491/3491 [==============================] - 40s 12ms/step - loss: 0.0482 - accuracy: 0.9632 - val_loss: 0.0517 - val_accuracy: 0.9910
# Epoch 6/10
# 3491/3491 [==============================] - 41s 12ms/step - loss: 0.0460 - accuracy: 0.9697 - val_loss: 0.0521 - val_accuracy: 0.9911
# Epoch 7/10
# 3491/3491 [==============================] - 41s 12ms/step - loss: 0.0456 - accuracy: 0.9761 - val_loss: 0.0502 - val_accuracy: 0.9859
# Epoch 8/10
# 3491/3491 [==============================] - 41s 12ms/step - loss: 0.0445 - accuracy: 0.9799 - val_loss: 0.0493 - val_accuracy: 0.9781
# Epoch 9/10
# 3491/3491 [==============================] - 41s 12ms/step - loss: 0.0433 - accuracy: 0.9618 - val_loss: 0.0498 - val_accuracy: 0.9877
# Epoch 10/10
# 3491/3491 [==============================] - 40s 12ms/step - loss: 0.0425 - accuracy: 0.9642 - val_loss: 0.0522 - val_accuracy: 0.9633
# 2021-02-10 23:34:40,963 accuracy:0.9191176470588235
# 2021-02-10 23:34:40,963
#               precision    recall  f1-score   support
#
#            0       0.86      0.70      0.77      4591
#            1       0.64      0.07      0.12       485
#            2       0.85      0.76      0.80      2527
#            3       0.00      0.00      0.00       131
#            4       0.72      0.69      0.70      2362
#            5       0.76      0.12      0.21       430
#
#    micro avg       0.82      0.65      0.73     10526
#    macro avg       0.64      0.39      0.44     10526
# weighted avg       0.80      0.65      0.70     10526
#  samples avg       0.98      0.96      0.95     10526
