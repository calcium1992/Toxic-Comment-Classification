# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/Toxic-Comment-Classification/')
for root, dirs, files in os.walk(".", topdown=False):
   for name in files:
      print(os.path.join(root, name))
# Out:
# ./hiera/model=transformer/hyperparameters.yaml
# ./hiera/model=naivebayes/hyperparameters.yaml
# ./hiera/model=cnn/hyperparameters.yaml
# ./hiera/model=cnnglove/hyperparameters.yaml
# ./hiera/default.yaml
# ./config/cnnglove_config.yaml
# ./config/cnn_config.yaml
# ./config/nb_config.yaml
# ./data/glove/glove.twitter.27B.200d.txt
# ./data/train.csv
# ./data/test.csv
# ./data/submission.csv
# ./module/__pycache__/__init__.cpython-36.pyc
# ./module/__pycache__/predictor.cpython-36.pyc
# ./module/__pycache__/trainer.cpython-36.pyc
# ./module/__pycache__/preprocessor.cpython-36.pyc
# ./module/model/__pycache__/naivebayes.cpython-36.pyc
# ./module/model/__pycache__/__init__.cpython-36.pyc
# ./module/model/__pycache__/transformer.cpython-36.pyc
# ./module/model/__pycache__/cnn.cpython-36.pyc
# ./module/model/naivebayes.py
# ./module/model/__init__.py
# ./module/model/transformer.py
# ./module/model/cnn.py
# ./module/__init__.py
# ./module/predictor.py
# ./module/trainer.py
# ./module/preprocessor.py
# ./README.md
# ./requirements.txt
# ./run_cnn.py
# ./run_nb.py
# ./run_cnnglove.py
# ./run_transformer.py
# ./RUN_IN_COLAB.ipynb

# %% [markdown]
# # Build Environment

# %%
# !pip3 install -r requirements.txt
# Out:
# Collecting himl
#   Downloading https://files.pythonhosted.org/packages/70/e0/9932afa4a3459adb0bb0c77c4400516bd423a40b7522fa387828e6abcf47/himl-0.7.0-py2.py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 2)) (1.19.5)
# Collecting pyyaml==5.1
#   Downloading https://files.pythonhosted.org/packages/9f/2c/9417b5c774792634834e730932745bc09a7d36754ca00acf1ccd1ac2594d/PyYAML-5.1.tar.gz (274kB)
#      |████████████████████████████████| 276kB 19.8MB/s
# Collecting folium==0.2.1
#   Downloading https://files.pythonhosted.org/packages/72/dd/75ced7437bfa7cb9a88b96ee0177953062803c3b4cde411a97d98c35adaf/folium-0.2.1.tar.gz (69kB)
#      |████████████████████████████████| 71kB 11.1MB/s
# WARNING: The candidate selected for download or install is a yanked version: 'urllib3' candidate (version 1.25 at https://files.pythonhosted.org/packages/81/9b/715e96377cc1f87e71d9d4259c6f88bf561a539622ba3042e73188e0bc2d/urllib3-1.25-py2.py3-none-any.whl#sha256=a08afe8b057ba35963364711a1f36d346375da0c118f611f35c0252375338c7c (from https://pypi.org/simple/urllib3/) (requires-python:>=2.7, !=3.0.*, !=3.1.*, !=3.2.*, !=3.3.*, <4))
# Reason for being yanked: Broken release
# Collecting urllib3==1.25.0
#   Downloading https://files.pythonhosted.org/packages/81/9b/715e96377cc1f87e71d9d4259c6f88bf561a539622ba3042e73188e0bc2d/urllib3-1.25-py2.py3-none-any.whl (149kB)
#      |████████████████████████████████| 153kB 52.0MB/s
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 6)) (2.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 7)) (1.1.5)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 8)) (0.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 9)) (2.4.3)
# Collecting boto3>=1.9.110
#   Downloading https://files.pythonhosted.org/packages/51/ab/2f0571fc563f0f62d419d101b827325f9ce8037b925b7180151f18ba05cb/boto3-1.17.5.tar.gz (100kB)
#      |████████████████████████████████| 102kB 13.3MB/s
# Collecting hvac>=0.9.3
#   Downloading https://files.pythonhosted.org/packages/93/1c/9b21b71ef202895dbfa5f3f4f4c48d1b96779c3c7b2b0518ad040418586c/hvac-0.10.8-py2.py3-none-any.whl (135kB)
#      |████████████████████████████████| 143kB 52.6MB/s
# Collecting backports.functools-lru-cache>=1.5
#   Downloading https://files.pythonhosted.org/packages/da/d1/080d2bb13773803648281a49e3918f65b31b7beebf009887a529357fd44a/backports.functools_lru_cache-1.6.1-py2.py3-none-any.whl
# Collecting deepmerge>=0.0.5
#   Downloading https://files.pythonhosted.org/packages/02/5b/65182f7f7f835e5b86aa16a7a9565ffbb00daad280156ebb03a8b39f5203/deepmerge-0.1.1-py2.py3-none-any.whl
# Collecting botocore>=1.12
#   Downloading https://files.pythonhosted.org/packages/5f/9a/9b453ac4c894906b956f1bf89a4e4ce541226cd177881848d03d38d83972/botocore-1.20.5-py2.py3-none-any.whl (7.2MB)
#      |████████████████████████████████| 7.2MB 54.5MB/s
# Collecting pathlib2>=2.3.4
#   Downloading https://files.pythonhosted.org/packages/e9/45/9c82d3666af4ef9f221cbb954e1d77ddbb513faf552aea6df5f37f1a4859/pathlib2-2.3.5-py2.py3-none-any.whl
# Collecting lru-cache>=0.2.3
#   Downloading https://files.pythonhosted.org/packages/1f/65/fb195865ef4c3c8f98b00531a4564c942e8f995fbc61ec7767881007ad8b/lru_cache-0.2.3.tar.gz
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.6/dist-packages (from folium==0.2.1->-r requirements.txt (line 4)) (2.11.3)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (1.1.2)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (0.3.3)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (2.4.1)
# Requirement already satisfied: grpcio~=1.32.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (1.32.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (1.12)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (1.6.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (3.3.0)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (0.10.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (3.12.4)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (3.7.4.3)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (1.15.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (1.12.1)
# Requirement already satisfied: h5py~=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (2.10.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (0.36.2)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 6)) (2.4.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->-r requirements.txt (line 7)) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->-r requirements.txt (line 7)) (2.8.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn->-r requirements.txt (line 8)) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->-r requirements.txt (line 9)) (1.4.1)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading https://files.pythonhosted.org/packages/07/cb/5f001272b6faeb23c1c9e0acc04d48eaaf5c862c17709d20e3469c6e0139/jmespath-0.10.0-py2.py3-none-any.whl
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/ea/43/4b4a1b26eb03a429a4c37ca7fdf369d938bd60018fc194e94b8379b0c77c/s3transfer-0.3.4-py2.py3-none-any.whl (69kB)
#      |████████████████████████████████| 71kB 9.5MB/s
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from hvac>=0.9.3->himl->-r requirements.txt (line 1)) (2.23.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2->folium==0.2.1->-r requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (3.3.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (53.0.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (1.25.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (0.4.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (1.0.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn->-r requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.21.0->hvac>=0.9.3->himl->-r requirements.txt (line 1)) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.21.0->hvac>=0.9.3->himl->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.21.0->hvac>=0.9.3->himl->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (3.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (4.7)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (4.2.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (3.4.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow->-r requirements.txt (line 6)) (3.1.0)
# Building wheels for collected packages: pyyaml, folium, boto3, lru-cache
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.1-cp36-cp36m-linux_x86_64.whl size=44075 sha256=bd1ec80982a7707dc7ea3f51d17e0dd407741d975dcd79ff973ac5a5ce096313
#   Stored in directory: /root/.cache/pip/wheels/ad/56/bc/1522f864feb2a358ea6f1a92b4798d69ac783a28e80567a18b
#   Building wheel for folium (setup.py) ... done
#   Created wheel for folium: filename=folium-0.2.1-cp36-none-any.whl size=79980 sha256=1e13d72b41b8407cefbde9bc17598354dcec53e80dcc207de71d6a1df617d8fb
#   Stored in directory: /root/.cache/pip/wheels/b8/09/f0/52d2ef419c2aaf4fb149f92a33e0008bdce7ae816f0dd8f0c5
#   Building wheel for boto3 (setup.py) ... done
#   Created wheel for boto3: filename=boto3-1.17.5-py2.py3-none-any.whl size=128765 sha256=2f4fde5b8703c25f07579b9625d6838155c92b8391426d2cca50c24b2127fc2b
#   Stored in directory: /root/.cache/pip/wheels/42/75/b3/9d08f4f31956e3d28102b0ce5802aa2212b61a5475e238edb7
#   Building wheel for lru-cache (setup.py) ... done
#   Created wheel for lru-cache: filename=lru_cache-0.2.3-cp36-none-any.whl size=3276 sha256=f6782117c73f2a8b89851c428e393768e31585a5369f681d5f19353b964762e8
#   Stored in directory: /root/.cache/pip/wheels/16/00/b3/959f58ff8314ecebc0190eaeb8a18bd2d6099efdca144fc118
# Successfully built pyyaml folium boto3 lru-cache
# ERROR: requests 2.23.0 has requirement urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you'll have urllib3 1.25 which is incompatible.
# ERROR: botocore 1.20.5 has requirement urllib3<1.27,>=1.25.4, but you'll have urllib3 1.25 which is incompatible.
# Installing collected packages: jmespath, urllib3, botocore, s3transfer, boto3, hvac, backports.functools-lru-cache, deepmerge, pathlib2, lru-cache, pyyaml, himl, folium
#   Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Found existing installation: folium 0.8.3
#     Uninstalling folium-0.8.3:
#       Successfully uninstalled folium-0.8.3
# Successfully installed backports.functools-lru-cache-1.6.1 boto3-1.17.5 botocore-1.20.5 deepmerge-0.1.1 folium-0.2.1 himl-0.7.0 hvac-0.10.8 jmespath-0.10.0 lru-cache-0.2.3 pathlib2-2.3.5 pyyaml-5.1 s3transfer-0.3.4 urllib3-1.25

# %% [markdown]
# # Run Naive Bayes

# %%
# !himl hiera/model=naivebayes/ --output-file config/nb_config.yaml

# %%
# !python run_nb.py --config config/nb_config.yaml
# Out:
# 2021-02-10 20:06:00.403164: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-10 20:06:44,063 accuracy:0.9037642045454546
# 2021-02-10 20:06:44,063
#               precision    recall  f1-score   support
#
#            0       0.79      0.60      0.68      4591
#            1       0.42      0.41      0.42       485
#            2       0.74      0.59      0.65      2527
#            3       0.14      0.03      0.05       131
#            4       0.68      0.53      0.59      2362
#            5       0.31      0.10      0.15       430
#
#    micro avg       0.72      0.55      0.62     10526
#    macro avg       0.51      0.38      0.43     10526
# weighted avg       0.71      0.55      0.61     10526
#  samples avg       0.98      0.95      0.93     10526

# %% [markdown]
# # Run CNN

# %%
# !himl hiera/model=cnn/ --output-file config/cnn_config.yaml

# %%
# !python run_cnn.py --config config/cnn_config.yaml
# Out:
# 2021-02-10 18:44:00.729773: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# /content/drive/My Drive/Colab Notebooks/Toxic-Comment-Classification/module/preprocessor.py:129: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(dataset_ids)
# 2021-02-10 18:44:46.592449: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-10 18:44:46.593796: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-02-10 18:44:46.644046: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 18:44:46.644673: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-02-10 18:44:46.644730: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-10 18:44:46.832994: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-02-10 18:44:46.833140: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-02-10 18:44:46.989046: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-02-10 18:44:47.002105: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-02-10 18:44:47.285204: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-02-10 18:44:47.296112: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-02-10 18:44:47.798720: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-02-10 18:44:47.798945: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 18:44:47.799592: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 18:44:47.802183: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-02-10 18:44:47.802688: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-10 18:44:47.802868: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 18:44:47.803422: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-02-10 18:44:47.803474: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-10 18:44:47.803518: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-02-10 18:44:47.803544: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-02-10 18:44:47.803569: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-02-10 18:44:47.803590: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-02-10 18:44:47.803610: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-02-10 18:44:47.803632: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-02-10 18:44:47.803656: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-02-10 18:44:47.803744: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 18:44:47.804314: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 18:44:47.804817: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-02-10 18:44:47.806625: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-10 18:44:51.842431: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-02-10 18:44:51.842485: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-02-10 18:44:51.842506: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-02-10 18:44:51.847046: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 18:44:51.847744: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 18:44:51.848332: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 18:44:51.848884: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-02-10 18:44:51.848937: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13960 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 128, 128)          21524224
# _________________________________________________________________
# conv1d (Conv1D)              (None, 128, 128)          114816
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 64, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 64, 256)           164096
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 32, 256)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 32, 512)           393728
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 16, 512)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1048704
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 774
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 42
# =================================================================
# Total params: 23,246,384
# Trainable params: 23,246,384
# Non-trainable params: 0
# _________________________________________________________________
# 2021-02-10 18:44:52.314070: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-02-10 18:44:52.320539: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2199995000 Hz
# Epoch 1/2
# 2021-02-10 18:44:53.149249: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-02-10 18:44:54.754214: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 3491/3491 [==============================] - 698s 198ms/step - loss: 0.0843 - accuracy: 0.8925 - val_loss: 0.0529 - val_accuracy: 0.9938
# Epoch 2/2
# 3491/3491 [==============================] - 684s 196ms/step - loss: 0.0437 - accuracy: 0.9822 - val_loss: 0.0506 - val_accuracy: 0.9938
# 2021-02-10 19:07:57,414 accuracy:0.9192429812834224
# 2021-02-10 19:07:57,414
#               precision    recall  f1-score   support
#
#            0       0.85      0.75      0.79      4591
#            1       0.75      0.01      0.02       485
#            2       0.82      0.74      0.78      2527
#            3       1.00      0.00      0.00       131
#            4       0.75      0.67      0.71      2362
#            5       1.00      0.00      0.00       430
#
#    micro avg       0.82      0.66      0.73     10526
#    macro avg       0.86      0.36      0.38     10526
# weighted avg       0.82      0.66      0.69     10526
#  samples avg       0.98      0.96      0.95     10526

# %% [markdown]
# # Run CNN with Glove

# %%
# !himl hiera/model=cnnglove/ --output-file config/cnnglove_config.yaml

# %%
# !python run_cnnglove.py --config config/cnnglove_config.yaml
# Out:
# 2021-02-10 20:28:05.843374: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# tcmalloc: large alloc 1909628928 bytes == 0x9ce02000 @  0x7f6a68167001 0x7f6a65ba54ff 0x7f6a65bf5b08 0x7f6a65bf9ac7 0x7f6a65c981a3 0x50a4a5 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03 0x634e72 0x634f27 0x6386df 0x639281 0x4b0dc0 0x7f6a67d62bf7 0x5b259a
# /content/drive/My Drive/Colab Notebooks/Toxic-Comment-Classification/module/preprocessor.py:129: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(dataset_ids)
# 2021-02-10 20:29:51.606382: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-10 20:29:51.616480: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-02-10 20:29:51.651239: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 20:29:51.651842: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-02-10 20:29:51.651883: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-10 20:29:51.661977: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-02-10 20:29:51.662062: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-02-10 20:29:51.667233: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-02-10 20:29:51.671671: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-02-10 20:29:51.679798: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-02-10 20:29:51.682368: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-02-10 20:29:51.693095: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-02-10 20:29:51.693242: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 20:29:51.693878: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 20:29:51.694383: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-02-10 20:29:51.694917: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-10 20:29:51.695061: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 20:29:51.695660: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-02-10 20:29:51.695712: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-10 20:29:51.695748: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-02-10 20:29:51.695770: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-02-10 20:29:51.695788: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-02-10 20:29:51.695808: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-02-10 20:29:51.695828: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-02-10 20:29:51.695847: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-02-10 20:29:51.695867: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-02-10 20:29:51.695937: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 20:29:51.696474: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 20:29:51.696975: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-02-10 20:29:51.697021: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-10 20:29:54.134370: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-02-10 20:29:54.134425: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-02-10 20:29:54.134442: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-02-10 20:29:54.139816: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 20:29:54.140434: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 20:29:54.141028: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-10 20:29:54.141589: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-02-10 20:29:54.141642: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13960 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2021-02-10 20:29:54.224290: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 954812800 exceeds 10% of free system memory.
# 2021-02-10 20:29:55.409571: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 954812800 exceeds 10% of free system memory.
# 2021-02-10 20:29:55.817492: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 954812800 exceeds 10% of free system memory.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 128, 200)          238703200
# _________________________________________________________________
# conv1d (Conv1D)              (None, 128, 128)          179328
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 64, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 64, 256)           164096
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 32, 256)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 32, 512)           393728
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 16, 512)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1048704
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 774
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 42
# =================================================================
# Total params: 240,489,872
# Trainable params: 1,786,672
# Non-trainable params: 238,703,200
# _________________________________________________________________
# 2021-02-10 20:29:56.797253: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-02-10 20:29:56.817990: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2199995000 Hz
# Epoch 1/2
# 2021-02-10 20:29:57.580913: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-02-10 20:30:00.167258: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 3491/3491 [==============================] - 33s 7ms/step - loss: 0.1010 - accuracy: 0.8353 - val_loss: 0.0544 - val_accuracy: 0.9938
# Epoch 2/2
# 3491/3491 [==============================] - 24s 7ms/step - loss: 0.0562 - accuracy: 0.9838 - val_loss: 0.0521 - val_accuracy: 0.9938
# 2021-02-10 20:30:56,810 accuracy:0.9184074197860963
# 2021-02-10 20:30:56,810
#               precision    recall  f1-score   support
#
#            0       0.87      0.69      0.77      4591
#            1       0.68      0.15      0.24       485
#            2       0.78      0.77      0.78      2527
#            3       1.00      0.00      0.00       131
#            4       0.71      0.68      0.70      2362
#            5       1.00      0.00      0.00       430
#
#    micro avg       0.80      0.65      0.72     10526
#    macro avg       0.84      0.38      0.42     10526
# weighted avg       0.81      0.65      0.69     10526
#  samples avg       0.98      0.96      0.95     10526
