# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/Toxic-Comment-Classification/')
for root, dirs, files in os.walk(".", topdown=False):
   for name in files:
      print(os.path.join(root, name))
# Out:
# ./hiera/model=transformer/hyperparameters.yaml
# ./hiera/model=cnn/hyperparameters.yaml
# ./hiera/model=cnnglove/hyperparameters.yaml
# ./hiera/model=nb/hyperparameters.yaml
# ./hiera/model=rnnglove/hyperparameters.yaml
# ./hiera/default.yaml
# ./config/nb_config.yaml
# ./config/cnn_config.yaml
# ./config/cnnglove_config.yaml
# ./config/transformer_config.yaml
# ./data/glove/glove.twitter.27B.200d.txt
# ./data/train.csv
# ./data/test.csv
# ./data/submission.csv
# ./module/model/__pycache__/naivebayes.cpython-36.pyc
# ./module/model/__pycache__/transformer.cpython-36.pyc
# ./module/model/__pycache__/__init__.cpython-36.pyc
# ./module/model/__pycache__/cnn.cpython-36.pyc
# ./module/model/__pycache__/rnn.cpython-36.pyc
# ./module/model/naivebayes.py
# ./module/model/transformer.py
# ./module/model/__init__.py
# ./module/model/cnn.py
# ./module/model/rnn.py
# ./module/__pycache__/__init__.cpython-36.pyc
# ./module/__pycache__/predictor.cpython-36.pyc
# ...

# %% [markdown]
# # Build Environment

# %%
# !pip3 install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 276kB 12.5MB/s
# ...
#      |████████████████████████████████| 71kB 9.9MB/s
# WARNING: The candidate selected for download or install is a yanked version: 'urllib3' candidate (version 1.25 at https://files.pythonhosted.org/packages/81/9b/715e96377cc1f87e71d9d4259c6f88bf561a539622ba3042e73188e0bc2d/urllib3-1.25-py2.py3-none-any.whl#sha256=a08afe8b057ba35963364711a1f36d346375da0c118f611f35c0252375338c7c (from https://pypi.org/simple/urllib3/) (requires-python:>=2.7, !=3.0.*, !=3.1.*, !=3.2.*, !=3.3.*, <4))
# Reason for being yanked: Broken release
# ...
#      |████████████████████████████████| 153kB 20.9MB/s
# ...
#      |████████████████████████████████| 143kB 27.4MB/s
# ...
#      |████████████████████████████████| 7.2MB 26.9MB/s
# ...
#      |████████████████████████████████| 133kB 54.1MB/s
# ...
#      |████████████████████████████████| 71kB 10.9MB/s
# ...

# %% [markdown]
# # Run Naive Bayes

# %%
# !himl hiera/model=naivebayes/ --output-file config/nb_config.yaml
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/himl", line 8, in <module>
#     sys.exit(run())
#   File "/usr/local/lib/python3.6/dist-packages/himl/main.py", line 70, in run
#     ConfigRunner().run(args)
#   File "/usr/local/lib/python3.6/dist-packages/himl/main.py", line 22, in run
#     self.do_run(opts)
#   File "/usr/local/lib/python3.6/dist-packages/himl/main.py", line 34, in do_run
#     opts.skip_interpolation_validation, opts.skip_secrets, opts.multi_line_string)
#   File "/usr/local/lib/python3.6/dist-packages/himl/config_generator.py", line 43, in process
#     generator = ConfigGenerator(cwd, path, multi_line_string)
#   File "/usr/local/lib/python3.6/dist-packages/himl/config_generator.py", line 121, in __init__
#     self.hierarchy = self.generate_hierarchy()
#   File "/usr/local/lib/python3.6/dist-packages/himl/config_generator.py", line 204, in generate_hierarchy
#     os.chdir(path)
# ...

# %%
# !python run_nb.py --config config/nb_config.yaml
# Out:
# 2021-02-11 22:19:48.903818: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-11 22:20:32,988 accuracy:0.9046246396791577, f1: 0.9316043358404555
# 2021-02-11 22:20:32,988
#               precision    recall  f1-score   support
#
#            0       0.79      0.63      0.70      1531
#            1       0.40      0.43      0.41       161
#            2       0.75      0.63      0.69       858
#            3       0.08      0.02      0.04        43
#            4       0.70      0.56      0.62       813
#            5       0.35      0.15      0.21       147
#
#    micro avg       0.72      0.58      0.64      3553
#    macro avg       0.51      0.40      0.45      3553
# weighted avg       0.72      0.58      0.64      3553
#  samples avg       0.98      0.95      0.93      3553

# %% [markdown]
# # Run CNN

# %%
# !himl hiera/model=cnn/ --output-file config/cnn_config.yaml

# %%
# !python run_cnn.py --config config/cnn_config.yaml
# Out:
# 2021-02-11 22:20:40.507603: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# /content/drive/My Drive/Colab Notebooks/Toxic-Comment-Classification/module/preprocessor.py:145: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(dataset_ids)
# 2021-02-11 22:21:22.379866: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-11 22:21:22.380935: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# ...

# %% [markdown]
# # Run CNN with GloVe

# %%
# !himl hiera/model=cnnglove/ --output-file config/cnnglove_config.yaml

# %%
# !python run_cnnglove.py --config config/cnnglove_config.yaml
# Out:
# 2021-02-11 22:56:09.653725: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# tcmalloc: large alloc 1909628928 bytes == 0x9cf3e000 @  0x7fe8931c1001 0x7fe890bff4ff 0x7fe890c4fb08 0x7fe890c53ac7 0x7fe890cf21a3 0x50a4a5 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03 0x634e72 0x634f27 0x6386df 0x639281 0x4b0dc0 0x7fe892dbcbf7 0x5b259a
# /content/drive/My Drive/Colab Notebooks/Toxic-Comment-Classification/module/preprocessor.py:145: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(dataset_ids)
# 2021-02-11 22:57:59.461697: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# ...

# %% [markdown]
# # Run RNN with GloVe

# %%
# !himl hiera/model=rnnglove/ --output-file config/rnnglove_config.yaml

# %%
# !python run_rnnglove.py --config config/rnnglove_config.yaml
# Out:
# 2021-02-18 03:28:22.693831: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# tcmalloc: large alloc 1909628928 bytes == 0x9d966000 @  0x7fbcec2f1001 0x7fbce9d2f4ff 0x7fbce9d7fb08 0x7fbce9d83ac7 0x7fbce9e221a3 0x50a4a5 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03 0x634e72 0x634f27 0x6386df 0x639281 0x4b0dc0 0x7fbcebeecbf7 0x5b259a
# /content/drive/My Drive/Colab Notebooks/Toxic-Comment-Classification/module/preprocessor.py:145: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(dataset_ids)
# 2021-02-18 03:30:12.002385: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# ...

# %% [markdown]
# # Run Transformer with GloVe

# %%
# !himl hiera/model=transformer/ --output-file config/transformer_config.yaml

# %%
# !python run_transformer.py --config config/transformer_config.yaml
# Out:
# 2021-02-11 22:59:26.305023: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# tcmalloc: large alloc 1909628928 bytes == 0x9d288000 @  0x7feb00a65001 0x7feafe4a34ff 0x7feafe4f3b08 0x7feafe4f7ac7 0x7feafe5961a3 0x50a4a5 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03 0x634e72 0x634f27 0x6386df 0x639281 0x4b0dc0 0x7feb00660bf7 0x5b259a
# /content/drive/My Drive/Colab Notebooks/Toxic-Comment-Classification/module/preprocessor.py:145: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(dataset_ids)
# 2021-02-11 23:01:09.654699: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# ...
